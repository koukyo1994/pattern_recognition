# %%
using Distributions 
using LinearLeastSquares
using Plots
# Out:
# INFO: Precompiling module Distributions.
#
# WARNING: deprecated syntax "function .*(...)".
# Use "function Base.broadcast(::typeof(*), ...)" instead.
#
# WARNING: deprecated syntax "function .*(...)".
# Use "function Base.broadcast(::typeof(*), ...)" instead.
#
# WARNING: deprecated syntax "function .*(...)".
# Use "function Base.broadcast(::typeof(*), ...)" instead.
#
# WARNING: deprecated syntax "function .*(...)".
# Use "function Base.broadcast(::typeof(*), ...)" instead.
#
# WARNING: deprecated syntax "function .*(...)".
# Use "function Base.broadcast(::typeof(*), ...)" instead.
#
# WARNING: deprecated syntax "function ./(...)".
# Use "function Base.broadcast(::typeof(/), ...)" instead.
# INFO: Precompiling module Reexport.
# INFO: Precompiling module StaticArrays.
# INFO: Precompiling module RecipesBase.
# INFO: Precompiling module PlotUtils.
# INFO: Precompiling module PlotThemes.
# INFO: Precompiling module Showoff.
# INFO: Precompiling module Requires.
# ...

# %%
dist = Normal(0.0, 0.05)
epsilon = rand(dist, 100)
x = collect(0.01:0.01:1)
f(x) = 0.5 + 0.4 .* sin(2pi.*x) .+ epsilon
# Out:
# f (generic function with 1 method)

# %%
gr()
plot(x, f(x))
# Out:
# WARNING: sin(x::AbstractArray{T}) where T <: Number is deprecated, use sin.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] sin(::Array{Float64,1}) at ./deprecated.jl:57
#  [3] f(::Array{Float64,1}) at ./In[2]:4
#  [4] include_string(::String, ::String) at ./loading.jl:522
#  [5] include_string(::Module, ::String, ::String) at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:174
#  [6] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/hidehisa/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [7] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:496
#  [8] eventloop(::ZMQ.Socket) at /home/hidehisa/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [9] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[3], in expression starting on line 2
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
scatter(x, f(x))
# Out:
# WARNING: sin(x::AbstractArray{T}) where T <: Number is deprecated, use sin.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] sin(::Array{Float64,1}) at ./deprecated.jl:57
#  [3] f(::Array{Float64,1}) at ./In[2]:4
#  [4] include_string(::String, ::String) at ./loading.jl:522
#  [5] include_string(::Module, ::String, ::String) at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:174
#  [6] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/hidehisa/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [7] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:496
#  [8] eventloop(::ZMQ.Socket) at /home/hidehisa/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [9] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[4], in expression starting on line 1
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
index = collect(1:10:91)
x_i = x[index]
f_i = f(x)[index]
# Out:
# WARNING: sin(x::AbstractArray{T}) where T <: Number is deprecated, use sin.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] sin(::Array{Float64,1}) at ./deprecated.jl:57
#  [3] f(::Array{Float64,1}) at ./In[2]:4
#  [4] include_string(::String, ::String) at ./loading.jl:522
#  [5] include_string(::Module, ::String, ::String) at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:174
#  [6] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/hidehisa/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [7] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:496
#  [8] eventloop(::ZMQ.Socket) at /home/hidehisa/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [9] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[5], in expression starting on line 3
# 10-element Array{Float64,1}:
#  0.492043
#  0.773742
#  0.822322
#  0.889438
#  0.772198
#  0.469454
#  0.102643
# ...

# %%
slope = Variable()
offset = Variable()
line = offset + x_i * slope
residuals = line - f_i
fit_error = sum_squares(residuals)
optval = minimize!(fit_error)
# Out:
# 0.41058372844340385

# %%
scatter(x, f(x))

y = evaluate(slope) * x + evaluate(offset)
plot!(x, y)
# Out:
# WARNING: sin(x::AbstractArray{T}) where T <: Number is deprecated, use sin.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] sin(::Array{Float64,1}) at ./deprecated.jl:57
#  [3] f(::Array{Float64,1}) at ./In[2]:4
#  [4] include_string(::String, ::String) at ./loading.jl:522
#  [5] include_string(::Module, ::String, ::String) at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:174
#  [6] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/hidehisa/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [7] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:496
#  [8] eventloop(::ZMQ.Socket) at /home/hidehisa/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [9] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[7], in expression starting on line 1
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
function linear_regression(x, f, n_dims)
    offset = Variable()
    coeffs = [Variable() for i in 1:n_dims]
    
    line = offset
    for i in 1:n_dims
        line += coeffs[i] * x .^ i
    end
    
    residuals = line - f
    fit_error = sum_squares(residuals)
    optval = minimize!(fit_error)
    return offset, coeffs, optval
end
# Out:
# linear_regression (generic function with 1 method)

# %%
offset, coeffs, optval = linear_regression(x_i, f_i, 3)
# Out:
# (Variable(1, 1), LinearLeastSquares.AffineExpr[Variable(1, 1), Variable(1, 1), Variable(1, 1)], 0.048148358347545536)

# %%
function fitted_curve(x, offset, coeffs)
    n_dims = length(coeffs)
    line = evaluate(offset)
    for i in 1:n_dims
        line += evaluate(coeffs[i]) * x .^ i
    end
    
    return line
end
# Out:
# fitted_curve (generic function with 1 method)

# %%
y = fitted_curve(x, offset, coeffs)
scatter(x, f(x))
plot!(x, y)
# Out:
# WARNING: sin(x::AbstractArray{T}) where T <: Number is deprecated, use sin.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] sin(::Array{Float64,1}) at ./deprecated.jl:57
#  [3] f(::Array{Float64,1}) at ./In[2]:4
#  [4] include_string(::String, ::String) at ./loading.jl:522
#  [5] include_string(::Module, ::String, ::String) at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:174
#  [6] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/hidehisa/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [7] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/hidehisa/.julia/v0.6/Compat/src/Compat.jl:496
#  [8] eventloop(::ZMQ.Socket) at /home/hidehisa/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [9] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[11], in expression starting on line 2
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
offset, coeffs = linear_regression(x_i, f_i, 6)
y = fitted_curve(x, offset, coeffs)
plot!(x, y)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0500)" points="
# 39.1436,375.813 580.315,375.813 580.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0502">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   49.3028,375.813 49.3028,11.811
#   "/>
# ...

# %%
offset, coeffs = linear_regression(x_i, f_i, 10)
y = fitted_curve(x, offset, coeffs)
plot!(x, y)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 28.9273,375.813 580.315,375.813 580.315,11.811 28.9273,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0702">
#     <rect x="28" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.2783,375.813 39.2783,11.811
#   "/>
# ...

# %%
dims = collect(1:10)
